# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = {'Pre-Trained Models':['VGG-16', 'Inception-V3', 'ResNet50', 'MobileNetV2'],
        'Score':[92.68, 88.61, 68.29, 91.05]}
  
df = pd.DataFrame(data, index =['rank1',
                                'rank2',
                                'rank3',
                                'rank4'])
  

df.to_csv('graphs.csv', index = False, header = True)
data = pd.read_csv('graphs.csv')

# %%
plt.figure(figsize=(18, 12))
splot=sns.barplot(x="Pre-Trained Models",y="Score",data=data)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xlabel("Pre-Trained Models", size=28)
plt.ylabel("score", size=28)
# Out:
# Text(0, 0.5, 'score')

# %%
X = ['VGG-16','Inception-V3','ResNet50','MobileNetV2']
precision = [92,88,68,91]
f1 = [92,88,68,91]
recall= [92,88,68,91]
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, precision, 0.2, label = 'Precision')
plt.bar(X_axis + 0.2, f1, 0.2, label = 'F-1')
plt.bar(X_axis + 0.0, recall, 0.2, label = 'Recall')
  
plt.xticks(X_axis, X)
plt.xlabel("Pre-Trained Models")
plt.ylabel("Score")
plt.title("Result Analyis")
plt.legend()
plt.show()

# %%
data = {'Pre-Trained Models':['Xception','VGG-16', 'Inception-V3', 'ResNet50', 'MobileNetV2'],
        'Score':[91.86,92.68, 88.61, 68.29, 91.05]}
  
df = pd.DataFrame(data, index =['rank1',
                                'rank2',
                                'rank3',
                                'rank4',
                                'rank5'])
  

df.to_csv('graphs2.csv', index = False, header = True)
data = pd.read_csv('graphs2.csv')

# %%
plt.figure(figsize=(18, 12))
splot=sns.barplot(x="Pre-Trained Models",y="Score",data=data)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xlabel("Pre-Trained Models", size=28)
plt.ylabel("score", size=28)
# Out:
# Text(0, 0.5, 'score')

# %%
X = ['Xception','VGG-16','Inception-V3','ResNet50','MobileNetV2']

precision = [91,92,88,68,91]
f1 = [92,92,88,68,91]
recall= [91,92,88,68,91]
X_axis = np.arange(len(X))


plt.bar(X_axis - 0.2, precision, 0.2, label = 'Precision')
plt.bar(X_axis + 0.2, f1, 0.2, label = 'F-1')
plt.bar(X_axis + 0.0, recall, 0.2, label = 'Recall')
  
plt.xticks(X_axis, X)
plt.xlabel("Pre-Trained Models")
plt.ylabel("Score")
plt.title("Result Analyis")
plt.legend()
plt.show()
